# %% [markdown]
# Catalog build sanity checker
# ============================
#
# This notebook is designed to do some basic sanity checking on new `access-nri-intake-catalog` catalog builds, and to examine the experiments that have made it into the new catalog.

# %% [markdown]
# Basic setup
# -----------

# %%
import numpy as np

# %%
import access_nri_intake

access_nri_intake.__version__
# Out:
# '1.2.2+9.g6c25b63.dirty'

# %% [markdown]
# Load catalog & compare to older catalog
# -----

# %%
import intake

cat = intake.cat.access_nri
cat
# Out:
# <p><strong>access_nri catalog with 112 source(s) across 2363 rows</strong>:</p> <div style='max-height: 300px; overflow: auto; width: fit-content'><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>model</th>
#       <th>description</th>
#       <th>realm</th>
#       <th>frequency</th>
#       <th>variable</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>01deg_jra55_ryf_Control</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1° ACCESS-OM2 repeat year forcing control run for the simulations performed in Huguenin et al. (2024, GRL)}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1mon, fx}</td>
#       <td>{temp_vdiffuse_diff_cbt, TLAT, temp_yflux_adv, kmu, sst_m, uocn_m, ty_trans_int_z, average_T2, vatm_m, ht, total_ocean_fprec_melt_heat, alvdf_ai_m, ke_tot, uatm_m, TLON, xu_ocean, sea_levelsq, sw_...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55_ryf_ENFull</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.1° ACCESS-OM2 El Níño run for the simulations performed in Huguenin et al. (2024, GRL)}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1mon, fx}</td>
#       <td>{temp_vdiffuse_diff_cbt, TLAT, kmu, uocn_m, ty_trans_int_z, average_T2, vatm_m, ht, total_ocean_fprec_melt_heat, alvdf_ai_m, ke_tot, uatm_m, TLON, xu_ocean, sea_levelsq, sw_ocean, average_T1, grid...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55_ryf_LNFull</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.1° ACCESS-OM2 La Níña run for the simulations performed in Huguenin et al. (2024, GRL)}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1mon, fx}</td>
#       <td>{temp_vdiffuse_diff_cbt, TLAT, kmu, uocn_m, ty_trans_int_z, average_T2, vatm_m, ht, total_ocean_fprec_melt_heat, alvdf_ai_m, ke_tot, uatm_m, TLON, xu_ocean, sea_levelsq, sw_ocean, average_T1, grid...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991)}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{3mon, fx, 3hr, 1day, 1mon}</td>
#       <td>{wfimelt, pot_temp, TLAT, temp_yflux_adv, kmu, uocn_m, ty_trans_int_z, pbot_t, average_T2, vatm_m, sfc_salt_flux_coupler, ht, total_ocean_fprec_melt_heat, alvdf_ai_m, ke_tot, uatm_m, TLON, xu_ocea...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_down10</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and zonal/meridional wind speed around Antarctica decreased by 10%.}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{wfimelt, pot_temp, TLAT, temp_yflux_adv, kmu, uocn_m, ty_trans_int_z, pbot_t, average_T2, vatm_m, sfc_salt_flux_coupler, ht, total_ocean_fprec_melt_heat, alvdf_ai_m, ke_tot, uatm_m, TLON, xu_ocea...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_up10</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and zonal/meridional wind speed around Antarctica increased by 10%.}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{wfimelt, pot_temp, TLAT, temp_yflux_adv, kmu, uocn_m, ty_trans_int_z, pbot_t, average_T2, vatm_m, sfc_salt_flux_coupler, ht, total_ocean_fprec_melt_heat, alvdf_ai_m, ke_tot, uatm_m, TLON, xu_ocea...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_up10_meridional</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and meridional wind speed around Antarctica increased by 10%.}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{wfimelt, pot_temp, TLAT, temp_yflux_adv, kmu, uocn_m, ty_trans_int_z, pbot_t, average_T2, vatm_m, sfc_salt_flux_coupler, ht, total_ocean_fprec_melt_heat, alvdf_ai_m, ke_tot, uatm_m, TLON, xu_ocea...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_up10_zonal</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and zonal wind speed around Antarctica increased by 10%.}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{wfimelt, pot_temp, TLAT, temp_yflux_adv, kmu, uocn_m, ty_trans_int_z, pbot_t, average_T2, vatm_m, sfc_salt_flux_coupler, ht, total_ocean_fprec_melt_heat, alvdf_ai_m, ke_tot, uatm_m, TLON, xu_ocea...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_qian_wthmp</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Future perturbations with wind, thermal and meltwater forcing, branching off 01deg_jra55v13_ryf9091, as described in Li et al.  2023, https://www.nature.com/articles/s41586-023-05762-w}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1mon, fx}</td>
#       <td>{wfimelt, bmf_u, pot_temp, temp_vdiffuse_diff_cbt, TLAT, kmu, uocn_m, ty_trans_int_z, pbot_t, average_T2, vatm_m, sfc_salt_flux_coupler, ht, total_ocean_fprec_melt_heat, alvdf_ai_m, ke_tot, uatm_m...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_qian_wthp</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Future perturbation with wind and thermal forcing, branching off 01deg_jra55v13_ryf9091, as described in Li et al.  2023, https://www.nature.com/articles/s41586-023-05762-w}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1mon, fx}</td>
#       <td>{wfimelt, bmf_u, pot_temp, temp_vdiffuse_diff_cbt, TLAT, kmu, uocn_m, ty_trans_int_z, pbot_t, average_T2, vatm_m, sfc_salt_flux_coupler, ht, total_ocean_fprec_melt_heat, alvdf_ai_m, ke_tot, uatm_m...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_weddell_down2</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Weddell Sea decreased meltwater perturbation experiment, branched off 01deg_jra55v13_ryf9091. }</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{wfimelt, pot_temp, TLAT, temp_yflux_adv, kmu, uocn_m, ty_trans_int_z, pbot_t, average_T2, vatm_m, sfc_salt_flux_coupler, ht, total_ocean_fprec_melt_heat, alvdf_ai_m, ke_tot, uatm_m, TLON, xu_ocea...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_weddell_up1</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Weddell Sea increased meltwater perturbation experiment, branched off 01deg_jra55v13_ryf9091. }</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{wfimelt, pot_temp, TLAT, temp_yflux_adv, kmu, uocn_m, ty_trans_int_z, pbot_t, average_T2, vatm_m, sfc_salt_flux_coupler, ht, total_ocean_fprec_melt_heat, alvdf_ai_m, ke_tot, uatm_m, TLON, xu_ocea...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Cycle 1 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{wfimelt, bmf_u, pot_temp, TLAT, temp_yflux_adv, kmu, dvidtt_m, pbot_t, average_T2, vatm_m, sfc_salt_flux_coupler, ht, total_ocean_fprec_melt_heat, alvdf_ai_m, ke_tot, uatm_m, TLON, xu_ocean, sw_o...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf_cycle2</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Cycle 2 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{wfimelt, bmf_u, pot_temp, TLAT, temp_yflux_adv, kmu, dvidtt_m, pbot_t, average_T2, vatm_m, sfc_sal

# %%
len(cat.df)
# Out:
# 2363

# %%
from access_nri_intake.data.utils import available_versions

available_versions()
# Out:
# v2025-05-20*
# v2025-03-04
# v2025-02-19
# v2025-02-18
# v2025-02-17
# v2024-12-10
# v2024-11-08
# v2024-10-02(-->v0.1.3)
# v2024-03-28(-->v0.1.2)
# v2024-03-04(-->v0.1.1)
# v2023-11-29(-->v0.1.0)
# v2023-09-29(-->v0.0.10)
# v2023-07-20(-->v0.0.9)
# v2023-07-10(-->v0.0.8)
# v2000-01-01

# %%
cat_old = intake.cat.access_nri(version="v2025-03-04")
cat_old
# Out:
# <p><strong>access_nri catalog with 113 source(s) across 2402 rows</strong>:</p> <div style='max-height: 300px; overflow: auto; width: fit-content'><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>model</th>
#       <th>description</th>
#       <th>realm</th>
#       <th>frequency</th>
#       <th>variable</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>01deg_jra55_ryf_Control</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1° ACCESS-OM2 repeat year forcing control run for the simulations performed in Huguenin et al. (2024, GRL)}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1mon, fx}</td>
#       <td>{temp_vdiffuse_diff_cbt, TLAT, temp_yflux_adv, kmu, sst_m, uocn_m, ty_trans_int_z, average_T2, vatm_m, ht, total_ocean_fprec_melt_heat, alvdf_ai_m, ke_tot, uatm_m, TLON, xu_ocean, sea_levelsq, sw_...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55_ryf_ENFull</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.1° ACCESS-OM2 El Níño run for the simulations performed in Huguenin et al. (2024, GRL)}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1mon, fx}</td>
#       <td>{temp_vdiffuse_diff_cbt, TLAT, kmu, uocn_m, ty_trans_int_z, average_T2, vatm_m, ht, total_ocean_fprec_melt_heat, alvdf_ai_m, ke_tot, uatm_m, TLON, xu_ocean, sea_levelsq, sw_ocean, average_T1, grid...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55_ryf_LNFull</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.1° ACCESS-OM2 La Níña run for the simulations performed in Huguenin et al. (2024, GRL)}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1mon, fx}</td>
#       <td>{temp_vdiffuse_diff_cbt, TLAT, kmu, uocn_m, ty_trans_int_z, average_T2, vatm_m, ht, total_ocean_fprec_melt_heat, alvdf_ai_m, ke_tot, uatm_m, TLON, xu_ocean, sea_levelsq, sw_ocean, average_T1, grid...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991)}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{3mon, fx, 3hr, 1day, 1mon}</td>
#       <td>{wfimelt, pot_temp, TLAT, temp_yflux_adv, kmu, uocn_m, ty_trans_int_z, pbot_t, average_T2, vatm_m, sfc_salt_flux_coupler, ht, total_ocean_fprec_melt_heat, alvdf_ai_m, ke_tot, uatm_m, TLON, xu_ocea...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_down10</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and zonal/meridional wind speed around Antarctica decreased by 10%.}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{wfimelt, pot_temp, TLAT, temp_yflux_adv, kmu, uocn_m, ty_trans_int_z, pbot_t, average_T2, vatm_m, sfc_salt_flux_coupler, ht, total_ocean_fprec_melt_heat, alvdf_ai_m, ke_tot, uatm_m, TLON, xu_ocea...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_up10</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and zonal/meridional wind speed around Antarctica increased by 10%.}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{wfimelt, pot_temp, TLAT, temp_yflux_adv, kmu, uocn_m, ty_trans_int_z, pbot_t, average_T2, vatm_m, sfc_salt_flux_coupler, ht, total_ocean_fprec_melt_heat, alvdf_ai_m, ke_tot, uatm_m, TLON, xu_ocea...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_up10_meridional</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and meridional wind speed around Antarctica increased by 10%.}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{wfimelt, pot_temp, TLAT, temp_yflux_adv, kmu, uocn_m, ty_trans_int_z, pbot_t, average_T2, vatm_m, sfc_salt_flux_coupler, ht, total_ocean_fprec_melt_heat, alvdf_ai_m, ke_tot, uatm_m, TLON, xu_ocea...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_up10_zonal</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and zonal wind speed around Antarctica increased by 10%.}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{wfimelt, pot_temp, TLAT, temp_yflux_adv, kmu, uocn_m, ty_trans_int_z, pbot_t, average_T2, vatm_m, sfc_salt_flux_coupler, ht, total_ocean_fprec_melt_heat, alvdf_ai_m, ke_tot, uatm_m, TLON, xu_ocea...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_qian_wthmp</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Future perturbations with wind, thermal and meltwater forcing, branching off 01deg_jra55v13_ryf9091, as described in Li et al.  2023, https://www.nature.com/articles/s41586-023-05762-w}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1mon, fx}</td>
#       <td>{wfimelt, bmf_u, pot_temp, temp_vdiffuse_diff_cbt, TLAT, kmu, uocn_m, ty_trans_int_z, pbot_t, average_T2, vatm_m, sfc_salt_flux_coupler, ht, total_ocean_fprec_melt_heat, alvdf_ai_m, ke_tot, uatm_m...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_qian_wthp</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Future perturbation with wind and thermal forcing, branching off 01deg_jra55v13_ryf9091, as described in Li et al.  2023, https://www.nature.com/articles/s41586-023-05762-w}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1mon, fx}</td>
#       <td>{wfimelt, bmf_u, pot_temp, temp_vdiffuse_diff_cbt, TLAT, kmu, uocn_m, ty_trans_int_z, pbot_t, average_T2, vatm_m, sfc_salt_flux_coupler, ht, total_ocean_fprec_melt_heat, alvdf_ai_m, ke_tot, uatm_m...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_weddell_down2</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Weddell Sea decreased meltwater perturbation experiment, branched off 01deg_jra55v13_ryf9091. }</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{wfimelt, pot_temp, TLAT, temp_yflux_adv, kmu, uocn_m, ty_trans_int_z, pbot_t, average_T2, vatm_m, sfc_salt_flux_coupler, ht, total_ocean_fprec_melt_heat, alvdf_ai_m, ke_tot, uatm_m, TLON, xu_ocea...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_weddell_up1</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Weddell Sea increased meltwater perturbation experiment, branched off 01deg_jra55v13_ryf9091. }</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{wfimelt, pot_temp, TLAT, temp_yflux_adv, kmu, uocn_m, ty_trans_int_z, pbot_t, average_T2, vatm_m, sfc_salt_flux_coupler, ht, total_ocean_fprec_melt_heat, alvdf_ai_m, ke_tot, uatm_m, TLON, xu_ocea...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Cycle 1 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{wfimelt, bmf_u, pot_temp, TLAT, temp_yflux_adv, kmu, dvidtt_m, pbot_t, average_T2, vatm_m, sfc_salt_flux_coupler, ht, total_ocean_fprec_melt_heat, alvdf_ai_m, ke_tot, uatm_m, TLON, xu_ocean, sw_o...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf_cycle2</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Cycle 2 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{wfimelt, bmf_u, pot_temp, TLAT, temp_yflux_adv, kmu, dvidtt_m, pbot_t, average_T2, vatm_m, sfc_sal

# %% [markdown]
# Examine new catalog
# ---

# %%
for exp in cat.keys():
    if exp not in cat_old.keys():
        print(f"New experiment: {exp}")

for exp in cat_old.keys():
    if exp not in cat.keys():
        print(f"Removed experiment: {exp}")
# Out:
# Removed experiment: barpa_py18

# %%
for exp in cat.keys():
    rows_new = len(cat.df[cat.df.name == exp])
    was_string = ""
    warn_string = ""
    rows_old = None
    if exp in cat_old.keys():
        rows_old = len(cat_old.df[cat_old.df.name == exp])
        was_string = f" (was {rows_old})"
        if rows_new != rows_old:
            warn_string = "<< CHANGE >> "
    print(f"{warn_string}Experiment {exp}: {len(cat.df[cat.df.name == exp])} rows{was_string}")
# Out:
# Experiment 1deg_jra55_iaf_omip2spunup_cycle14: 3 rows (was 3)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle18: 3 rows (was 3)
# Experiment 01deg_jra55v13_ryf9091_weddell_down2: 4 rows (was 4)
# Experiment 025deg_jra55_iaf_omip2_cycle6: 5 rows (was 5)
# Experiment shackleton_v4_jk72: 1 rows (was 1)
# Experiment 1deg_jra55_iaf_omip2_cycle4: 6 rows (was 6)
# Experiment 01deg_jra55v13_ryf9091: 6 rows (was 6)
# Experiment HI_nl_C_05_r1: 7 rows (was 7)
# Experiment PI_GWL_B2035: 6 rows (was 6)
# Experiment cj877: 7 rows (was 7)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle34: 5 rows (was 5)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle33: 3 rows (was 3)
# << CHANGE >> Experiment cmip6_oi10: 931 rows (was 930)
# Experiment 1deg_era5_iaf: 5 rows (was 5)
# Experiment by578: 6 rows (was 6)
# Experiment 01deg_jra55v13_ryf9091_easterlies_up10: 4 rows (was 4)
# Experiment HI_noluc_CN_05: 9 rows (was 9)
# Experiment 01deg_jra55v13_ryf9091_weddell_up1: 4 rows (was 4)
# Experiment 1deg_jra55_iaf_omip2_cycle3: 6 rows (was 6)
# Experiment 1deg_jra55_iaf_omip2_cycle6: 6 rows (was 6)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle27: 3 rows (was 3)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle16: 3 rows (was 3)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle2: 6 rows (was 6)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle10: 3 rows (was 3)
# Experiment 01deg_jra55_ryf_LNFull: 3 rows (was 3)
# Experiment PI_GWL_B2050: 6 rows (was 6)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle26: 3 rows (was 3)
# Experiment bz687: 6 rows (was 6)
# Experiment PI_GWL_B2045: 6 rows (was 6)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle32: 3 rows (was 3)
# Experiment 025deg_jra55_iaf_omip2_cycle4: 6 rows (was 6)
# Experiment 025deg_jra55_iaf_omip2_cycle3: 6 rows (was 6)
# Experiment 1deg_jra55_ryf9091_gadi: 4 rows (was 4)
# Experiment 01deg_jra55v150_iaf_cycle1: 5 rows (was 5)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle4: 6 rows (was 6)
# Experiment era5_rt52: 9 rows (was 9)
# Experiment 1deg_jra55_iaf_era5comparison: 5 rows (was 5)
# Experiment 025deg_jra55_iaf_omip2_cycle1: 6 rows (was 6)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle31: 3 rows (was 3)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle21: 3 rows (was 3)
# Experiment PI_GWL_B2055: 6 rows (was 6)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle13: 3 rows (was 3)
# Experiment panant-01-hycom1-v13: 5 rows (was 5)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle35: 5 rows (was 5)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle20: 3 rows (was 3)
# Experiment 01deg_jra55v13_ryf9091_qian_wthmp: 3 rows (was 3)
# Experiment 01deg_jra55_ryf_ENFull: 3 rows (was 3)
# Experiment HI_C_05_r1: 7 rows (was 7)
# Experiment 01deg_jra55_ryf_Control: 3 rows (was 3)
# Experiment by647: 6 rows (was 6)
# Experiment 1deg_jra55_iaf_omip2_cycle2: 6 rows (was 6)
# Experiment panant-01-zstar-v13: 5 rows (was 5)
# Experiment 1deg_jra55v14_ryf: 5 rows (was 5)
# Experiment 025deg_era5_iaf: 5 rows (was 5)
# Experiment 01deg_jra55v140_iaf_cycle4: 8 rows (was 8)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle25: 3 rows (was 3)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle3: 6 rows (was 6)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle42: 3 rows (was 3)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle22: 3 rows (was 3)
# Experiment 01deg_jra55v140_iaf_cycle3: 5 rows (was 5)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle7: 4 rows (was 4)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle8: 3 rows (was 3)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle45: 3 rows (was 3)
# Experiment 1deg_jra55_iaf_omip2_cycle5: 6 rows (was 6)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle28: 3 rows (was 3)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle43: 3 rows (was 3)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle1: 6 rows (was 6)
# Experiment bx944: 6 rows (was 6)
# Experiment 01deg_jra55v13_ryf9091_easterlies_up10_meridional: 4 rows (was 4)
# Experiment 025deg_jra55_iaf_omip2_cycle2: 6 rows (was 6)
# Experiment by473: 6 rows (was 6)
# Experiment 01deg_jra55v140_iaf_cycle4_jra55v150_extension: 6 rows (was 6)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle11: 3 rows (was 3)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle38: 5 rows (was 5)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle12: 3 rows (was 3)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle19: 3 rows (was 3)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle29: 3 rows (was 3)
# Experiment 01deg_jra55v140_iaf_cycle2: 5 rows (was 5)
# Experiment 025deg_jra55_iaf_omip2_cycle5: 6 rows (was 6)
# Experiment 01deg_jra55v13_ryf9091_easterlies_down10: 4 rows (was 4)
# Experiment 01deg_jra55v13_ryf9091_qian_wthp: 3 rows (was 3)
# Experiment PI_GWL_B2060: 6 rows (was 6)
# Experiment narclim2_zz63: 25 rows (was 25)
# << CHANGE >> Experiment rcm_ccam_hq89: 5 rows (was 40)
# Experiment cmip6_fs38: 60 rows (was 60)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle15: 3 rows (was 3)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle36: 5 rows (was 5)
# Experiment 01deg_jra55v13_ryf9091_easterlies_up10_zonal: 4 rows (was 4)
# Experiment cmip5_al33: 717 rows (was 717)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle41: 3 rows (was 3)
# Experiment 025deg_jra55_ryf9091_gadi: 4 rows (was 4)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle17: 3 rows (was 3)
# Experiment 025deg_jra55_iaf_era5comparison: 5 rows (was 5)
# Experiment 025deg_era5_ryf: 5 rows (was 5)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle9: 3 rows (was 3)
# Experiment 1deg_jra55_iaf_omip2_cycle1: 6 rows (was 6)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle44: 3 rows (was 3)
# Experiment cmip5_rr3: 132 rows (was 132)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle37: 5 rows (was 5)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle23: 3 rows (was 3)
# Experiment 1deg_era5_ryf: 5 rows (was 5)
# Experiment 025deg_jra55_ryf_era5comparison: 5 rows (was 5)
# Experiment PI_GWL_B2040: 6 rows (was 6)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle40: 3 rows (was 3)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle5: 5 rows (was 5)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle6: 5 rows (was 5)
# Experiment 01deg_jra55v140_iaf: 5 rows (was 5)
# Experiment HI_CN_05: 9 rows (was 9)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle30: 3 rows (was 3)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle24: 3 rows (was 3)
# Experiment OM4_025.JRA_RYF: 6 rows (was 6)
# Experiment 1deg_jra55_iaf_omip2spunup_cycle39: 5 rows (was 5)

# %%
np.unique(cat.df.model)
# Out:
# array([('ACCESS-CM2',), ('ACCESS-ESM1-5',), ('ACCESS-OM2',),
#        ('ACCESS-OM2-01',), ('ACCESS-OM2-025',), ('ACCESS1-0',),
#        ('ACCESS1-3',), ('AWI-CM-1-1-MR',), ('AWI-ESM-1-1-LR',),
#        ('AWI-ESM-1-REcoM',), ('BCC-CSM2-HR',), ('BCC-CSM2-MR',),
#        ('BCC-ESM1',), ('BNU-ESM',), ('CAMS-CSM1-0',), ('CAS-ESM2-0',),
#        ('CCCma-CanESM2',), ('CCSM4',), ('CESM1-1-CAM5-CMIP5',),
#        ('CESM1-BGC',), ('CESM1-CAM5',), ('CESM1-CAM5-1-FV2',),
#        ('CESM1-CAM5-SE-HR',), ('CESM1-CAM5-SE-LR',), ('CESM1-FASTCHEM',),
#        ('CESM1-WACCM',), ('CESM2',), ('CESM2-FV2',), ('CESM2-WACCM',),
#        ('CESM2-WACCM-FV2',), ('CFSv2-2011',), ('CIESM',), ('CMCC-CESM',),
#        ('CMCC-CM',), ('CMCC-CM2-HR4',), ('CMCC-CM2-SR5',),
#        ('CMCC-CM2-VHR4',), ('CMCC-CMS',), ('CMCC-ESM2',),
#        ('CNRM-CERFACS-CNRM-CM5',), ('CNRM-CERFACS-CNRM-CM6-1-HR',),
#        ('CNRM-CM5',), ('CNRM-CM5-2',), ('CNRM-CM6-1',),
#        ('CNRM-CM6-1-HR',), ('CNRM-ESM2-1',), ('CSIRO-BOM-ACCESS1-0',),
#        ('CSIRO-BOM-ACCESS1-3',), ('CSIRO-Mk3-6-0',), ('CSIRO-Mk3L-1-2',),
#        ('CSIRO-QCCCE-CSIRO-Mk3-6-0',), ('CanAM4',), ('CanCM4',),
#        ('CanESM2',), ('CanESM5',), ('CanESM5-1',), ('CanESM5-CanOE',),
#        ('E3SM-1-0',), ('E3SM-1-1',), ('E3SM-1-1-ECA',), ('E3SM-2-0',),
#        ('E3SM-2-0-NARRM',), ('EC-EARTH',), ('EC-Earth3',),
#        ('EC-Earth3-AerChem',), ('EC-Earth3-CC',), ('EC-Earth3-HR',),
#        ('EC-Earth3-LR',), ('EC-Earth3-Veg',), ('EC-Earth3-Veg-LR',),
#        ('EC-Earth3P',), ('EC-Earth3P-HR',), ('ECMWF-ERAINT',),
#        ('ECMWF-IFS-HR',), ('ECMWF-IFS-LR',), ('ECMWF-IFS-MR',),
#        ('FGOALS-f3-H',), ('FGOALS-f3-L',), ('FGOALS-g2',), ('FGOALS-g3',),
#        ('FGOALS-gl',), ('FGOALS-s2',), ('FIO-ESM',), ('FIO-ESM-2-0',),
#        ('GEOS-5',), ('GFDL-AM4',), ('GFDL-CM2p1',), ('GFDL-CM3',),
#        ('GFDL-CM4',), ('GFDL-CM4C192',), ('GFDL-ESM2G',), ('GFDL-ESM2M',),
#        ('GFDL-ESM4',), ('GFDL-HIRAM-C180',), ('GFDL-HIRAM-C360',),
#        ('GFDL-OM4p5B',), ('GISS-E2-1-G',), ('GISS-E2-1-G-CC',),
#        ('GISS-E2-1-H',), ('GISS-E2-2-G',), ('GISS-E2-2-H',),
#        ('GISS-E2-H',), ('GISS-E2-H-CC',), ('GISS-E2-R',),
#        ('GISS-E2-R-CC',), ('HadCM3',), ('HadGEM2-A',), ('HadGEM2-AO',),
#        ('HadGEM2-CC',), ('HadGEM2-ES',), ('HadGEM3-GC31-HH',),
#        ('HadGEM3-GC31-HM',), ('HadGEM3-GC31-LL',), ('HadGEM3-GC31-LM',),
#        ('HadGEM3-GC31-MM',), ('HiRAM-SIT-HR',), ('HiRAM-SIT-LR',),
#        ('ICHEC-EC-EARTH',), ('ICON-ESM-LR',), ('IITM-ESM',),
#        ('INM-CM4-8',), ('INM-CM5-0',), ('INM-CM5-H',), ('IPSL-CM5A-LR',),
#        ('IPSL-CM5A-MR',), ('IPSL-CM5A2-INCA',), ('IPSL-CM5B-LR',),
#        ('IPSL-CM6A-ATM-HR',), ('IPSL-CM6A-ATM-ICO-VHR',),
#        ('IPSL-CM6A-LR',), ('IPSL-CM6A-LR-INCA',), ('IPSL-IPSL-CM5A-LR',),
#        ('IPSL-IPSL-CM5A-MR',), ('KACE-1-0-G',), ('KIOST-ESM',),
#        ('MCM-UA-1-0',), ('MIROC-ES2H',), ('MIROC-ES2L',), ('MIROC-ESM',),
#        ('MIROC-ESM-CHEM',), ('MIROC-MIROC5',), ('MIROC4h',), ('MIROC5',),
#        ('MIROC6',), ('MOHC-HadGEM2-CC',), ('MOHC-HadGEM2-ES',),
#        ('MOM6', 'SIS2'), ('MPI-ESM-1-2-HAM',), ('MPI-ESM-LR',),
#        ('MPI-ESM-MR',), ('MPI-ESM-P',), ('MPI-ESM1-2-HR',),
#        ('MPI-ESM1-2-LR',), ('MPI-ESM1-2-XR',), ('MPI-M-MPI-ESM-LR',),
#        ('MPI-M-MPI-ESM-MR',), ('MRI-AGCM3-2-H',), ('MRI-AGCM3-2-S',),
#        ('MRI-AGCM3-2H',), ('MRI-AGCM3-2S',), ('MRI-CGCM3',),
#        ('MRI-ESM1',), ('MRI-ESM2-0',), ('NCAR-CCSM4',),
#        ('NCC-NorESM1-M',), ('NESM3',), ('NICAM16-7S',), ('NICAM16-8S',),
#        ('NICAM16-9S',), ('NOAA-GFDL-GFDL-CM3',),
#        ('NOAA-GFDL-GFDL-ESM2G',), ('NOAA-GFDL-GFDL-ESM2M',), ('NorCPM1',),
#        ('NorESM1-F',), ('NorESM1-M',), ('NorESM1-ME',), ('NorESM2-LM',),
#        ('NorESM2-MM',), ('ROMSIceShelf',), ('SAM0-UNICON',), ('TaiESM1',),
#        ('TaiESM1-TIMCOM',), ('TaiESM1-TIMCOM2',), ('UKESM1-0-LL',),
#        ('UKESM1-1-LL',), ('bcc-csm1-1',), ('bcc-csm1-1-m',), ('era5',),
#        ('era5-1',), ('era5-derived',), ('era5-preliminary',), ('era5t',),
#        ('fio-esm',), ('gfdl-esm2m',), ('inmcm4',), ('miroc5',)],
#       dtype=object)

# %%
cat.search(model=".*MOM6").df.model
# Out:
# 2312    (MOM6,)
# 2313    (MOM6,)
# 2314    (MOM6,)
# 2315    (MOM6,)
# 2316    (MOM6,)
# 2317    (MOM6,)
# 2318    (MOM6,)
# 2319    (MOM6,)
# 2320    (MOM6,)
# 2321    (MOM6,)
# 2322    (MOM6,)
# 2323    (MOM6,)
# 2324    (MOM6,)
# 2325    (MOM6,)
# 2326    (MOM6,)
# 2327    (MOM6,)
# Name: model, dtype: object
