# %% [markdown]
# Catalog build sanity checker
# ============================
#
# This notebook is designed to do some basic sanity checking on new `access-nri-intake-catalog` catalog builds, and to examine the experiments that have made it into the new catalog.

# %% [markdown]
# Basic setup
# -----------

# %%
import numpy as np

# %%
import access_nri_intake

access_nri_intake.__version__
# Out:
# '1.1.1'

# %% [markdown]
# Load catalog & compare to older catalog
# -----

# %%
import intake

cat = intake.cat.access_nri
cat
# Out:
# <p><strong>access_nri catalog with 113 source(s) across 2402 rows</strong>:</p> <div style='max-height: 300px; overflow: auto; width: fit-content'><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>model</th>
#       <th>description</th>
#       <th>realm</th>
#       <th>frequency</th>
#       <th>variable</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>01deg_jra55_ryf_Control</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1° ACCESS-OM2 repeat year forcing control run for the simulations performed in Huguenin et al. (2024, GRL)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1mon, fx}</td>
#       <td>{temp_rivermix, total_ocean_hflux_coupler, total_ocean_heat, dxt, dxu, geolat_c, sfc_hflux_pme_on_nrho, uarea, sfc_hflux_from_runoff, sss_m, tau_x, grid_yu_ocean, total_ocean_salt, neutral, v, ty_...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55_ryf_ENFull</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.1° ACCESS-OM2 El Níño run for the simulations performed in Huguenin et al. (2024, GRL)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1mon, fx}</td>
#       <td>{temp_rivermix, total_ocean_hflux_coupler, total_ocean_heat, dxt, dxu, geolat_c, uarea, sfc_hflux_from_runoff, sss_m, tau_x, grid_yu_ocean, total_ocean_salt, neutral, v, scalar_axis, uatm_m, total...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55_ryf_LNFull</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.1° ACCESS-OM2 La Níña run for the simulations performed in Huguenin et al. (2024, GRL)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1mon, fx}</td>
#       <td>{temp_rivermix, total_ocean_hflux_coupler, total_ocean_heat, dxt, dxu, geolat_c, uarea, sfc_hflux_from_runoff, sss_m, tau_x, grid_yu_ocean, total_ocean_salt, neutral, v, scalar_axis, uatm_m, total...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1mon, fx, 1day, 3hr, 3mon}</td>
#       <td>{temp_vdiffuse_impl, temp_rivermix, pbot_t, u_dot_grad_vert_pv, total_ocean_hflux_coupler, total_ocean_heat, dxt, dxu, geolat_c, uarea, sfc_hflux_from_runoff, sss_m, tau_x, yu_ocean_sub01, grid_yu...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_down10</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and zonal/meridional wind speed around Antarctica decreased by 10%.}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon, 1day}</td>
#       <td>{pbot_t, u_dot_grad_vert_pv, total_ocean_hflux_coupler, total_ocean_heat, dxt, dxu, geolat_c, uarea, sfc_hflux_from_runoff, sss_m, tau_x, grid_yu_ocean, total_ocean_salt, neutral, wfiform, v, scal...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_up10</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and zonal/meridional wind speed around Antarctica increased by 10%.}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon, 1day}</td>
#       <td>{pbot_t, u_dot_grad_vert_pv, total_ocean_hflux_coupler, total_ocean_heat, dxt, dxu, geolat_c, uarea, sfc_hflux_from_runoff, sss_m, tau_x, grid_yu_ocean, total_ocean_salt, neutral, wfiform, v, scal...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_up10_meridional</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and meridional wind speed around Antarctica increased by 10%.}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon, 1day}</td>
#       <td>{pbot_t, u_dot_grad_vert_pv, total_ocean_hflux_coupler, total_ocean_heat, dxt, dxu, geolat_c, uarea, sfc_hflux_from_runoff, sss_m, tau_x, grid_yu_ocean, total_ocean_salt, neutral, wfiform, v, scal...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_up10_zonal</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and zonal wind speed around Antarctica increased by 10%.}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon, 1day}</td>
#       <td>{pbot_t, u_dot_grad_vert_pv, total_ocean_hflux_coupler, total_ocean_heat, dxt, dxu, geolat_c, uarea, sfc_hflux_from_runoff, sss_m, tau_x, grid_yu_ocean, total_ocean_salt, neutral, wfiform, v, scal...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_qian_wthmp</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Future perturbations with wind, thermal and meltwater forcing, branching off 01deg_jra55v13_ryf9091, as described in Li et al.  2023, https://www.nature.com/articles/s41586-023-05762-w}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1mon, fx}</td>
#       <td>{temp_rivermix, pbot_t, u_dot_grad_vert_pv, total_ocean_hflux_coupler, total_ocean_heat, dxt, dxu, geolat_c, uarea, sfc_hflux_from_runoff, sss_m, tau_x, grid_yu_ocean, total_ocean_salt, wfiform, v...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_qian_wthp</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Future perturbation with wind and thermal forcing, branching off 01deg_jra55v13_ryf9091, as described in Li et al.  2023, https://www.nature.com/articles/s41586-023-05762-w}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1mon, fx}</td>
#       <td>{temp_rivermix, pbot_t, u_dot_grad_vert_pv, total_ocean_hflux_coupler, total_ocean_heat, dxt, dxu, geolat_c, uarea, sfc_hflux_from_runoff, sss_m, tau_x, grid_yu_ocean, total_ocean_salt, wfiform, v...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_weddell_down2</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Weddell Sea decreased meltwater perturbation experiment, branched off 01deg_jra55v13_ryf9091. }</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon, 1day}</td>
#       <td>{pbot_t, u_dot_grad_vert_pv, total_ocean_hflux_coupler, total_ocean_heat, dxt, dxu, geolat_c, uarea, sfc_hflux_from_runoff, sss_m, tau_x, grid_yu_ocean, total_ocean_salt, neutral, wfiform, v, scal...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_weddell_up1</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Weddell Sea increased meltwater perturbation experiment, branched off 01deg_jra55v13_ryf9091. }</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon, 1day}</td>
#       <td>{pbot_t, u_dot_grad_vert_pv, total_ocean_hflux_coupler, total_ocean_heat, dxt, dxu, geolat_c, uarea, sfc_hflux_from_runoff, sss_m, tau_x, grid_yu_ocean, total_ocean_salt, neutral, wfiform, v, scal...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Cycle 1 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon, 1day}</td>
#       <td>{pbot_t, total_ocean_heat, u_dot_grad_vert_pv, dxt, dxu, geolat_c, uarea, sfc_hflux_from_runoff, temp_yflux_adv_int_z, tau_x, grid_yu_ocean, vicen, total_ocean_salt, neutral, wfiform, v, scalar_ax...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf_cycle2</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Cycle 2 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon, 1day}</td>
#       <td>{daidtt, pbot_t, total_ocean_heat, u_dot_grad_vert_pv, dxt, dxu, geolat_c, uarea, sfc_hflux_from_ru

# %%
len(cat.df)
# Out:
# 2402

# %%
from access_nri_intake.data.utils import available_versions

available_versions()
# Out:
# v2025-03-04*
# v2025-02-19
# v2025-02-18
# v2025-02-17
# v2024-12-10
# v2024-11-08
# v2024-10-02(-->v0.1.3)
# v2024-03-28(-->v0.1.2)
# v2024-03-04(-->v0.1.1)
# v2023-11-29(-->v0.1.0)
# v2023-09-29(-->v0.0.10)
# v2023-07-20(-->v0.0.9)
# v2023-07-10(-->v0.0.8)
# v2000-01-01

# %%
cat_old = intake.cat.access_nri(version="v2025-02-19")
cat_old
# Out:
# <p><strong>access_nri catalog with 112 source(s) across 2400 rows</strong>:</p> <div style='max-height: 300px; overflow: auto; width: fit-content'><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>model</th>
#       <th>description</th>
#       <th>realm</th>
#       <th>frequency</th>
#       <th>variable</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>01deg_jra55_ryf_Control</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1° ACCESS-OM2 repeat year forcing control run for the simulations performed in Huguenin et al. (2024, GRL)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1mon, fx}</td>
#       <td>{temp_rivermix, total_ocean_hflux_coupler, total_ocean_heat, dxt, dxu, geolat_c, sfc_hflux_pme_on_nrho, uarea, sfc_hflux_from_runoff, sss_m, tau_x, grid_yu_ocean, total_ocean_salt, neutral, v, ty_...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55_ryf_ENFull</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.1° ACCESS-OM2 El Níño run for the simulations performed in Huguenin et al. (2024, GRL)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1mon, fx}</td>
#       <td>{temp_rivermix, total_ocean_heat, dxt, dxu, geolat_c, uarea, sfc_hflux_from_runoff, sss_m, tau_x, grid_yu_ocean, total_ocean_salt, neutral, v, scalar_axis, uatm_m, average_T1, eta_global, total_oc...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55_ryf_LNFull</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.1° ACCESS-OM2 La Níña run for the simulations performed in Huguenin et al. (2024, GRL)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1mon, fx}</td>
#       <td>{temp_rivermix, total_ocean_heat, dxt, dxu, geolat_c, uarea, sfc_hflux_from_runoff, sss_m, tau_x, grid_yu_ocean, total_ocean_salt, neutral, v, scalar_axis, uatm_m, average_T1, eta_global, total_oc...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1mon, fx, 1day, 3hr, 3mon}</td>
#       <td>{temp_vdiffuse_impl, temp_rivermix, pbot_t, total_ocean_hflux_coupler, total_ocean_heat, u_dot_grad_vert_pv, dxt, dxu, geolat_c, uarea, sfc_hflux_from_runoff, sss_m, tau_x, yu_ocean_sub01, grid_yu...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_down10</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and zonal/meridional wind speed around Antarctica decreased by 10%.}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon, 1day}</td>
#       <td>{pbot_t, total_ocean_hflux_coupler, total_ocean_heat, u_dot_grad_vert_pv, dxt, dxu, geolat_c, uarea, sfc_hflux_from_runoff, sss_m, tau_x, grid_yu_ocean, total_ocean_salt, wfiform, neutral, v, scal...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_up10</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and zonal/meridional wind speed around Antarctica increased by 10%.}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon, 1day}</td>
#       <td>{pbot_t, total_ocean_hflux_coupler, total_ocean_heat, u_dot_grad_vert_pv, dxt, dxu, geolat_c, uarea, sfc_hflux_from_runoff, sss_m, tau_x, grid_yu_ocean, total_ocean_salt, wfiform, neutral, v, scal...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_up10_meridional</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and meridional wind speed around Antarctica increased by 10%.}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon, 1day}</td>
#       <td>{pbot_t, total_ocean_hflux_coupler, total_ocean_heat, u_dot_grad_vert_pv, dxt, dxu, geolat_c, uarea, sfc_hflux_from_runoff, sss_m, tau_x, grid_yu_ocean, total_ocean_salt, wfiform, neutral, v, scal...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_easterlies_up10_zonal</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991) and zonal wind speed around Antarctica increased by 10%.}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon, 1day}</td>
#       <td>{pbot_t, total_ocean_hflux_coupler, total_ocean_heat, u_dot_grad_vert_pv, dxt, dxu, geolat_c, uarea, sfc_hflux_from_runoff, sss_m, tau_x, grid_yu_ocean, total_ocean_salt, wfiform, neutral, v, scal...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_qian_wthmp</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Future perturbations with wind, thermal and meltwater forcing, branching off 01deg_jra55v13_ryf9091, as described in Li et al.  2023, https://www.nature.com/articles/s41586-023-05762-w}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1mon, fx}</td>
#       <td>{temp_rivermix, pbot_t, total_ocean_hflux_coupler, total_ocean_heat, u_dot_grad_vert_pv, dxt, dxu, geolat_c, uarea, sfc_hflux_from_runoff, sss_m, tau_x, grid_yu_ocean, total_ocean_salt, wfiform, v...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_qian_wthp</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Future perturbation with wind and thermal forcing, branching off 01deg_jra55v13_ryf9091, as described in Li et al.  2023, https://www.nature.com/articles/s41586-023-05762-w}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1mon, fx}</td>
#       <td>{temp_rivermix, pbot_t, total_ocean_hflux_coupler, total_ocean_heat, u_dot_grad_vert_pv, dxt, dxu, geolat_c, uarea, sfc_hflux_from_runoff, sss_m, tau_x, grid_yu_ocean, total_ocean_salt, wfiform, v...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_weddell_down2</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Weddell Sea decreased meltwater perturbation experiment, branched off 01deg_jra55v13_ryf9091. }</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon, 1day}</td>
#       <td>{pbot_t, total_ocean_hflux_coupler, total_ocean_heat, u_dot_grad_vert_pv, dxt, dxu, geolat_c, uarea, sfc_hflux_from_runoff, sss_m, tau_x, grid_yu_ocean, total_ocean_salt, wfiform, neutral, v, scal...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v13_ryf9091_weddell_up1</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Weddell Sea increased meltwater perturbation experiment, branched off 01deg_jra55v13_ryf9091. }</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon, 1day}</td>
#       <td>{pbot_t, total_ocean_hflux_coupler, total_ocean_heat, u_dot_grad_vert_pv, dxt, dxu, geolat_c, uarea, sfc_hflux_from_runoff, sss_m, tau_x, grid_yu_ocean, total_ocean_salt, wfiform, neutral, v, scal...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Cycle 1 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon, 1day}</td>
#       <td>{pbot_t, total_ocean_heat, u_dot_grad_vert_pv, dxt, dxu, geolat_c, uarea, sfc_hflux_from_runoff, temp_yflux_adv_int_z, tau_x, grid_yu_ocean, vicen, total_ocean_salt, wfiform, neutral, v, scalar_ax...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf_cycle2</th>
#       <td>{ACCESS-OM2-01}</td>
#       <td>{Cycle 2 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{fx, 1mon, 1day}</td>
#       <td>{daidtt, pbot_t, total_ocean_heat, u_dot_grad_vert_pv, dxt, dxu, geolat_c, uarea, sfc_hflux_from_ru

# %%
len(cat_old.df)
# Out:
# 2400

# %% [markdown]
# Examine new catalog
# ---

# %%
for exp in cat.keys():
    if exp not in cat_old.keys():
        print(f"New experiment: {exp}")
# Out:
# New experiment: shackleton_v4_jk72

# %%
from distributed import Client

client = Client(threads_per_worker=1)
client.dashboard_link
# Out:
# '/proxy/8787/status'

# %%
for exp in cat.keys():
    print(f"Experiment {exp:48s}: {len(cat[exp].df):7d} dataframe rows")
# Out:
# Experiment 1deg_jra55_iaf_omip2spunup_cycle19              :     915 dataframe rows
# Experiment 1deg_jra55_iaf_era5comparison                   :    7860 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle27              :     915 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle15              :     915 dataframe rows
# Experiment 025deg_jra55_iaf_omip2_cycle6                   :    1830 dataframe rows
# Experiment 1deg_jra55_iaf_omip2_cycle3                     :    2013 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle39              :    1281 dataframe rows
# Experiment 025deg_jra55_iaf_omip2_cycle3                   :    1808 dataframe rows
# Experiment 025deg_jra55_iaf_era5comparison                 :    4883 dataframe rows
# Experiment 01deg_jra55v13_ryf9091_weddell_up1              :     639 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle3               :    2013 dataframe rows
# Experiment by647                                           :    1350 dataframe rows
# Experiment 1deg_jra55_iaf_omip2_cycle4                     :    2013 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle29              :     915 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle9               :     915 dataframe rows
# Experiment 01deg_jra55v150_iaf_cycle1                      :   22848 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle45              :     915 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle35              :    1281 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle37              :    1281 dataframe rows
# Experiment 01deg_jra55_ryf_ENFull                          :      80 dataframe rows
# Experiment 025deg_era5_iaf                                 :    4884 dataframe rows
# Experiment 01deg_jra55v140_iaf_cycle2                      :   24954 dataframe rows
# Experiment bz687                                           :   58266 dataframe rows
# Experiment 1deg_jra55_iaf_omip2_cycle6                     :    2013 dataframe rows
# Experiment 01deg_jra55v13_ryf9091_qian_wthmp               :    1800 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle16              :     915 dataframe rows
# Experiment 01deg_jra55v140_iaf_cycle4_jra55v150_extension  :   14273 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle31              :     915 dataframe rows
# Experiment panant-01-zstar-v13                             :    2136 dataframe rows
# Experiment 01deg_jra55v140_iaf_cycle4                      :  131730 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle6               :    1281 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle5               :    1281 dataframe rows
# Experiment OM4_025.JRA_RYF                                 :    1140 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle8               :     915 dataframe rows
# Experiment HI_noluc_CN_05                                  :    9435 dataframe rows
# Experiment cmip6_oi10                                      : 3412113 dataframe rows
# Experiment HI_nl_C_05_r1                                   :    7875 dataframe rows
# Experiment PI_GWL_B2035                                    :   43000 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle2               :    2013 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle42              :     915 dataframe rows
# Experiment 025deg_jra55_iaf_omip2_cycle5                   :    1769 dataframe rows
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.02/lib/python3.11/site-packages/intake_esm/cat.py:250: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
# Experiment cj877                                           :  116522 dataframe rows
# Experiment HI_C_05_r1                                      :    7873 dataframe rows
# Experiment cmip5_al33                                      : 3701323 dataframe rows
# Experiment 025deg_jra55_ryf_era5comparison                 :    3224 dataframe rows
# Experiment 1deg_jra55v14_ryf                               :   10100 dataframe rows
# Experiment era5_rt52                                       :  810082 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle24              :     915 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle11              :     915 dataframe rows
# Experiment by578                                           :    1350 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle7               :     927 dataframe rows
# Experiment barpa_py18                                      :  987568 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle26              :     915 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle21              :     915 dataframe rows
# Experiment cmip5_rr3                                       : 2858922 dataframe rows
# Experiment 01deg_jra55v13_ryf9091_easterlies_down10        :     480 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle17              :     915 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle10              :     915 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle34              :    1281 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle44              :     915 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle13              :     915 dataframe rows
# Experiment PI_GWL_B2045                                    :   43000 dataframe rows
# Experiment 01deg_jra55v13_ryf9091                          :   11947 dataframe rows
# Experiment 01deg_jra55v140_iaf                             :   25924 dataframe rows
# Experiment 1deg_jra55_ryf9091_gadi                         :    9677 dataframe rows
# Experiment 025deg_era5_ryf                                 :    3310 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle36              :    1281 dataframe rows
# Experiment 01deg_jra55_ryf_Control                         :     126 dataframe rows
# Experiment 1deg_jra55_iaf_omip2_cycle1                     :    2013 dataframe rows
# Experiment PI_GWL_B2055                                    :   43000 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle43              :     915 dataframe rows
# Experiment 01deg_jra55v13_ryf9091_easterlies_up10          :     480 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle20              :     915 dataframe rows
# Experiment rcm_ccam_hq89                                   :  637228 dataframe rows
# Experiment 01deg_jra55v13_ryf9091_weddell_down2            :     531 dataframe rows
# Experiment 1deg_jra55_iaf_omip2_cycle5                     :    2013 dataframe rows
# Experiment 025deg_jra55_iaf_omip2_cycle2                   :    1769 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle18              :     915 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle12              :     915 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle30              :     915 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle28              :     915 dataframe rows
# Experiment PI_GWL_B2060                                    :   43000 dataframe rows
# Experiment by473                                           :   12149 dataframe rows
# Experiment 025deg_jra55_iaf_omip2_cycle4                   :    1769 dataframe rows
# Experiment 025deg_jra55_iaf_omip2_cycle1                   :    1769 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle4               :    1989 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle25              :     915 dataframe rows
# Experiment narclim2_zz63                                   : 2492315 dataframe rows
# Experiment 01deg_jra55v13_ryf9091_qian_wthp                :    2160 dataframe rows
# Experiment PI_GWL_B2040                                    :   43000 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle14              :     915 dataframe rows
# Experiment 01deg_jra55v140_iaf_cycle3                      :   29438 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle33              :     915 dataframe rows
# Experiment 01deg_jra55v13_ryf9091_easterlies_up10_meridional:     336 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle38              :    1281 dataframe rows
# Experiment 1deg_era5_ryf                                   :   10100 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle1               :    2013 dataframe rows
# Experiment shackleton_v4_jk72                              :      26 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle22              :     915 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle32              :     915 dataframe rows
# Experiment 025deg_jra55_ryf9091_gadi                       :    8951 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle23              :     915 dataframe rows
# Experiment panant-01-hycom1-v13                            :     280 dataframe rows
# Experiment bx944                                           :   12150 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle41              :    4575 dataframe rows
# Experiment 1deg_jra55_iaf_omip2_cycle2                     :    2013 dataframe rows
# Experiment cmip6_fs38                                      : 1054133 dataframe rows
# Experiment 1deg_jra55_iaf_omip2spunup_cycle40              :     915 dataframe rows
# Experiment 1deg_era5_iaf                                   :    7965 dataframe rows
# Experiment 01deg_jra55v13_ryf9091_easterlies_up10_zonal    :     336 dataframe rows
# Experiment HI_CN_05                                        :    9435 dataframe rows
# Experiment 01deg_jra55_ryf_LNFull                          :     112 dataframe rows
# Experiment PI_GWL_B2050                                    :   43000 dataframe rows

# %%
len(cat.df)
# Out:
# 2402

# %%
np.unique(cat.df.model)
# Out:
# array([('ACCESS-CM2',), ('ACCESS-ESM1-5',), ('ACCESS-OM2',),
#        ('ACCESS-OM2-01',), ('ACCESS-OM2-025',), ('ACCESS1-0',),
#        ('ACCESS1-3',), ('AWI-CM-1-1-MR',), ('AWI-ESM-1-1-LR',),
#        ('AWI-ESM-1-REcoM',), ('BARPA-R',), ('BCC-CSM2-HR',),
#        ('BCC-CSM2-MR',), ('BCC-ESM1',), ('BNU-ESM',), ('CAMS-CSM1-0',),
#        ('CAS-ESM2-0',), ('CCCma-CanESM2',), ('CCSM4',),
#        ('CESM1-1-CAM5-CMIP5',), ('CESM1-BGC',), ('CESM1-CAM5',),
#        ('CESM1-CAM5-1-FV2',), ('CESM1-CAM5-SE-HR',),
#        ('CESM1-CAM5-SE-LR',), ('CESM1-FASTCHEM',), ('CESM1-WACCM',),
#        ('CESM2',), ('CESM2-FV2',), ('CESM2-WACCM',), ('CESM2-WACCM-FV2',),
#        ('CFSv2-2011',), ('CIESM',), ('CMCC-CESM',), ('CMCC-CM',),
#        ('CMCC-CM2-HR4',), ('CMCC-CM2-SR5',), ('CMCC-CM2-VHR4',),
#        ('CMCC-CMS',), ('CMCC-ESM2',), ('CNRM-CERFACS-CNRM-CM5',),
#        ('CNRM-CERFACS-CNRM-CM6-1-HR',), ('CNRM-CM5',), ('CNRM-CM5-2',),
#        ('CNRM-CM6-1',), ('CNRM-CM6-1-HR',), ('CNRM-ESM2-1',),
#        ('CSIRO-BOM-ACCESS1-0',), ('CSIRO-BOM-ACCESS1-3',),
#        ('CSIRO-Mk3-6-0',), ('CSIRO-Mk3L-1-2',),
#        ('CSIRO-QCCCE-CSIRO-Mk3-6-0',), ('CanAM4',), ('CanCM4',),
#        ('CanESM2',), ('CanESM5',), ('CanESM5-1',), ('CanESM5-CanOE',),
#        ('E3SM-1-0',), ('E3SM-1-1',), ('E3SM-1-1-ECA',), ('E3SM-2-0',),
#        ('E3SM-2-0-NARRM',), ('EC-EARTH',), ('EC-Earth3',),
#        ('EC-Earth3-AerChem',), ('EC-Earth3-CC',), ('EC-Earth3-HR',),
#        ('EC-Earth3-LR',), ('EC-Earth3-Veg',), ('EC-Earth3-Veg-LR',),
#        ('EC-Earth3P',), ('EC-Earth3P-HR',), ('ECMWF-ERAINT',),
#        ('ECMWF-IFS-HR',), ('ECMWF-IFS-LR',), ('ECMWF-IFS-MR',), ('ERA5',),
#        ('FGOALS-f3-H',), ('FGOALS-f3-L',), ('FGOALS-g2',), ('FGOALS-g3',),
#        ('FGOALS-gl',), ('FGOALS-s2',), ('FIO-ESM',), ('FIO-ESM-2-0',),
#        ('GEOS-5',), ('GFDL-AM4',), ('GFDL-CM2p1',), ('GFDL-CM3',),
#        ('GFDL-CM4',), ('GFDL-CM4C192',), ('GFDL-ESM2G',), ('GFDL-ESM2M',),
#        ('GFDL-ESM4',), ('GFDL-HIRAM-C180',), ('GFDL-HIRAM-C360',),
#        ('GFDL-OM4p5B',), ('GISS-E2-1-G',), ('GISS-E2-1-G-CC',),
#        ('GISS-E2-1-H',), ('GISS-E2-2-G',), ('GISS-E2-2-H',),
#        ('GISS-E2-H',), ('GISS-E2-H-CC',), ('GISS-E2-R',),
#        ('GISS-E2-R-CC',), ('HadCM3',), ('HadGEM2-A',), ('HadGEM2-AO',),
#        ('HadGEM2-CC',), ('HadGEM2-ES',), ('HadGEM3-GC31-HH',),
#        ('HadGEM3-GC31-HM',), ('HadGEM3-GC31-LL',), ('HadGEM3-GC31-LM',),
#        ('HadGEM3-GC31-MM',), ('HiRAM-SIT-HR',), ('HiRAM-SIT-LR',),
#        ('ICHEC-EC-EARTH',), ('ICON-ESM-LR',), ('IITM-ESM',),
#        ('INM-CM4-8',), ('INM-CM5-0',), ('INM-CM5-H',), ('IPSL-CM5A-LR',),
#        ('IPSL-CM5A-MR',), ('IPSL-CM5A2-INCA',), ('IPSL-CM5B-LR',),
#        ('IPSL-CM6A-ATM-HR',), ('IPSL-CM6A-ATM-ICO-VHR',),
#        ('IPSL-CM6A-LR',), ('IPSL-CM6A-LR-INCA',), ('IPSL-IPSL-CM5A-LR',),
#        ('IPSL-IPSL-CM5A-MR',), ('KACE-1-0-G',), ('KIOST-ESM',),
#        ('MCM-UA-1-0',), ('MIROC-ES2H',), ('MIROC-ES2L',), ('MIROC-ESM',),
#        ('MIROC-ESM-CHEM',), ('MIROC-MIROC5',), ('MIROC4h',), ('MIROC5',),
#        ('MIROC6',), ('MOHC-HadGEM2-CC',), ('MOHC-HadGEM2-ES',),
#        ('MOM6', 'SIS2'), ('MPI-ESM-1-2-HAM',), ('MPI-ESM-LR',),
#        ('MPI-ESM-MR',), ('MPI-ESM-P',), ('MPI-ESM1-2-HR',),
#        ('MPI-ESM1-2-LR',), ('MPI-ESM1-2-XR',), ('MPI-M-MPI-ESM-LR',),
#        ('MPI-M-MPI-ESM-MR',), ('MRI-AGCM3-2-H',), ('MRI-AGCM3-2-S',),
#        ('MRI-AGCM3-2H',), ('MRI-AGCM3-2S',), ('MRI-CGCM3',),
#        ('MRI-ESM1',), ('MRI-ESM2-0',), ('NCAR-CCSM4',),
#        ('NCC-NorESM1-M',), ('NESM3',), ('NICAM16-7S',), ('NICAM16-8S',),
#        ('NICAM16-9S',), ('NOAA-GFDL-GFDL-CM3',),
#        ('NOAA-GFDL-GFDL-ESM2G',), ('NOAA-GFDL-GFDL-ESM2M',), ('NorCPM1',),
#        ('NorESM1-F',), ('NorESM1-M',), ('NorESM1-ME',), ('NorESM2-LM',),
#        ('NorESM2-MM',), ('ROMSIceShelf',), ('SAM0-UNICON',), ('TaiESM1',),
#        ('TaiESM1-TIMCOM',), ('TaiESM1-TIMCOM2',), ('UKESM1-0-LL',),
#        ('UKESM1-1-LL',), ('bcc-csm1-1',), ('bcc-csm1-1-m',), ('era5',),
#        ('era5-1',), ('era5-derived',), ('era5-preliminary',), ('era5t',),
#        ('fio-esm',), ('gfdl-esm2m',), ('inmcm4',), ('miroc5',)],
#       dtype=object)

# %%
cat.search(model=".*MOM6").df.model
# Out:
# 2351    (MOM6,)
# 2352    (MOM6,)
# 2353    (MOM6,)
# 2354    (MOM6,)
# 2355    (MOM6,)
# 2356    (MOM6,)
# 2357    (MOM6,)
# 2358    (MOM6,)
# 2359    (MOM6,)
# 2360    (MOM6,)
# 2361    (MOM6,)
# 2362    (MOM6,)
# 2363    (MOM6,)
# 2364    (MOM6,)
# 2365    (MOM6,)
# 2366    (MOM6,)
# Name: model, dtype: object

# %%
np.unique(cat.df.variable).shape
# Out:
# (1148,)

# %%
cat.keys()[-1]
# Out:
# 'PI_GWL_B2050'

# %%
cat['shackleton_v4_jk72'].df.head()
# Out:
#            filename        file_id  \
# 0  roms_his_0001.nc  roms_his_XXXX
# 1  roms_his_0002.nc  roms_his_XXXX
# 2  roms_his_0003.nc  roms_his_XXXX
# 3  roms_his_0004.nc  roms_his_XXXX
# 4  roms_his_0005.nc  roms_his_XXXX
#
#                                                             path  \
# 0  /g/data/jk72/deg581/shacom/mdl/shackleton_v4/roms_his_0001.nc
# 1  /g/data/jk72/deg581/shacom/mdl/shackleton_v4/roms_his_0002.nc
# 2  /g/data/jk72/deg581/shacom/mdl/shackleton_v4/roms_his_0003.nc
# 3  /g/data/jk72/deg581/shacom/mdl/shackleton_v4/roms_his_0004.nc
# 4  /g/data/jk72/deg581/shacom/mdl/shackleton_v4/roms_his_0005.nc
#
#    filename_timestamp frequency            start_date              end_date  \
# 0                   1      5day  2006-12-29, 12:00:00  2008-01-03, 12:00:00
# 1                   2      5day  2008-01-03, 12:00:00  2009-01-02, 12:00:00
# 2                   3      5day  2009-01-02, 12:00:00  2010-01-02, 12:00:00
# 3                   4      5day  2010-01-02, 12:00:00  2011-01-02, 12:00:00
# 4                   5      5day  2011-01-02, 12:00:00  2012-01-02, 12:00:00
#
#                                                                                                                                                                                                   variable  \
# 0  [ntimes, ndtfast, dt, dtfast, dstart, nHIS, ndefHIS, nRST, ntsAVG, nAVG, ndefAVG, Falpha, Fbeta, Fgamma, nl_tnu2, nl_visc2, LuvSponge, LtracerSponge, Akt_bak, Akv_bak, rdrg, rdrg2, Zob, Zos, Znudg...
# 1  [ntimes, ndtfast, dt, dtfast, dstart, nHIS, ndefHIS, nRST, ntsAVG, nAVG, ndefAVG, Falpha, Fbeta, Fgamma, nl_tnu2, nl_visc2, LuvSponge, LtracerSponge, Akt_bak, Akv_bak, rdrg, rdrg2, Zob, Zos, Znudg...
# 2  [ntimes, ndtfast, dt, dtfast, dstart, nHIS, ndefHIS, nRST, ntsAVG, nAVG, ndefAVG, Falpha, Fbeta, Fgamma, nl_tnu2, nl_visc2, LuvSponge, LtracerSponge, Akt_bak, Akv_bak, rdrg, rdrg2, Zob, Zos, Znudg...
# 3  [ntimes, ndtfast, dt, dtfast, dstart, nHIS, ndefHIS, nRST, ntsAVG, nAVG, ndefAVG, Falpha, Fbeta, Fgamma, nl_tnu2, nl_visc2, LuvSponge, LtracerSponge, Akt_bak, Akv_bak, rdrg, rdrg2, Zob, Zos, Znudg...
# 4  [ntimes, ndtfast, dt, dtfast, dstart, nHIS, ndefHIS, nRST, ntsAVG, nAVG, ndefAVG, Falpha, Fbeta, Fgamma, nl_tnu2, nl_visc2, LuvSponge, LtracerSponge, Akt_bak, Akv_bak, rdrg, rdrg2, Zob, Zos, Znudg...
#
#                                                                                                                                                                                         variable_long_name  \
# 0  [number of long time-steps, number of short time-steps, size of long time-steps, size of short time-steps, time stamp assigned to model initilization, number of time-steps between history records,...
# 1  [number of long time-steps, number of short time-steps, size of long time-steps, size of short time-steps, time stamp assigned to model initilization, number of time-steps between history records,...
# 2  [number of long time-steps, number of short time-steps, size of long time-steps, size of short time-steps, time stamp assigned to model initilization, number of time-steps between history records,...
# 3  [number of long time-steps, number of short time-steps, size of long time-steps, size of short time-steps, time stamp assigned to model initilization, number of time-steps between history records,...
# 4  [number of long time-steps, number of short time-steps, size of long time-steps, size of short time-steps, time stamp assigned to model initilization, number of time-steps between history records,...
#
#                                                                                                                                                                                     variable_standard_name  \
# 0  [, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ocean_s_coordinate_g2, ocean_s_coordinate_g2, , , sea_floor_depth, , coriolis_par...
# 1  [, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ocean_s_coordinate_g2, ocean_s_coordinate_g2, , , sea_floor_depth, , coriolis_par...
# 2  [, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ocean_s_coordinate_g2, ocean_s_coordinate_g2, , , sea_floor_depth, , coriolis_par...
# 3  [, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ocean_s_coordinate_g2, ocean_s_coordinate_g2, , , sea_floor_depth, , coriolis_par...
# 4  [, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ocean_s_coordinate_g2, ocean_s_coordinate_g2, , , sea_floor_depth, , coriolis_par...
#
#                                                                                                                                                                                      variable_cell_methods  \
# 0  [, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ocean_time: point, ocean_time: poin...
# 1  [, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ocean_time: point, ocean_time: poin...
# 2  [, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ocean_time: point, ocean_time: poin...
# 3  [, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ocean_time: point, ocean_time: poin...
# 4  [, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ocean_time: point, ocean_time: poin...
#
#                                                                                                                                                                                             variable_units  \
# 0  [, , second, second, days since 2007-01-01 00:00:00, , , , , , , , , , meter2 second-1, meter2 second-1, , , meter2 second-1, meter2 second-1, meter second-1, , meter, meter, day-1, day-1, day-1, ...
# 1  [, , second, second, days since 2007-01-01 00:00:00, , , , , , , , , , meter2 second-1, meter2 second-1, , , meter2 second-1, meter2 second-1, meter second-1, , meter, meter, day-1, day-1, day-1, ...
# 2  [, , second, second, days since 2007-01-01 00:00:00, , , , , , , , , , meter2 second-1, meter2 second-1, , , meter2 second-1, meter2 second-1, meter second-1, , meter, meter, day-1, day-1, day-1, ...
# 3  [, , second, second, days since 2007-01-01 00:00:00, , , , , , , , , , meter2 second-1, meter2 second-1, , , meter2 second-1, meter2 second-1, meter second-1, , meter, meter, day-1, day-1, day-1, ...
# 4  [, , second, second, days since 2007-01-01 00:00:00, , , , , , , , , , meter2 second-1, meter2 second-1, , , meter2 second-1, meter2 second-1, meter second-1, , meter, meter, day-1, day-1, day-1, ...
#
#     realm
# 0  seaIce
# 1  seaIce
# 2  seaIce
# 3  seaIce
# 4  seaIce

# %%
client.close()
