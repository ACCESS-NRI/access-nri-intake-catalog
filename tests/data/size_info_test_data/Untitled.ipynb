# %%
import intake

cat = intake.cat.access_nri
cat
# Out:
# <p><strong>access_nri catalog with 113 source(s) across 2402 rows</strong>:</p> <div style='max-height: 300px; overflow: auto; width: fit-content'><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>model</th>
#       <th>description</th>
#       <th>realm</th>
#       <th>frequency</th>
#       <th>variable</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>01deg_jra55_ryf_Control</th>
#       <td>{ACCESS-OM2-01}</td>
# ...

# %%
cat.search(model="ROMSIceShelf")
# Out:
# <p><strong>Intake dataframe catalog with 1 source(s) across 1 rows</strong>:</p> <div style='max-height: 300px; overflow: auto; width: fit-content'><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>model</th>
#       <th>description</th>
#       <th>realm</th>
#       <th>frequency</th>
#       <th>variable</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>shackleton_v4_jk72</th>
#       <td>{ROMSIceShelf}</td>
#       <td>{Shackleton/Denman Ice Shelf-ocean model application built with ROMSIceShelf}</td>
# ...

# %%
jk72 = cat['shackleton_v4_jk72']
jk72
# Out:
# <p><strong>shackleton_v4_jk72 catalog with 1 dataset(s) from 26 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>filename</th>
#       <td>26</td>
#     </tr>
#     <tr>
#       <th>file_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>26</td>
#     </tr>
#     <tr>
#       <th>filename_timestamp</th>
#       <td>26</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>start_date</th>
#       <td>26</td>
#     </tr>
#     <tr>
#       <th>end_date</th>
#       <td>26</td>
# ...

# %%
jk72.df.head()
# Out:
#            filename        file_id  \
# 0  roms_his_0001.nc  roms_his_XXXX
# 1  roms_his_0002.nc  roms_his_XXXX
# 2  roms_his_0003.nc  roms_his_XXXX
# 3  roms_his_0004.nc  roms_his_XXXX
# 4  roms_his_0005.nc  roms_his_XXXX
#
#                                                             path  \
# 0  /g/data/jk72/deg581/shacom/mdl/shackleton_v4/roms_his_0001.nc
# 1  /g/data/jk72/deg581/shacom/mdl/shackleton_v4/roms_his_0002.nc
# 2  /g/data/jk72/deg581/shacom/mdl/shackleton_v4/roms_his_0003.nc
# 3  /g/data/jk72/deg581/shacom/mdl/shackleton_v4/roms_his_0004.nc
# 4  /g/data/jk72/deg581/shacom/mdl/shackleton_v4/roms_his_0005.nc
#
#    filename_timestamp frequency            start_date              end_date  \
# 0                   1      5day  2006-12-29, 12:00:00  2008-01-03, 12:00:00
# 1                   2      5day  2008-01-03, 12:00:00  2009-01-02, 12:00:00
# 2                   3      5day  2009-01-02, 12:00:00  2010-01-02, 12:00:00
# ...
